# %%
from sidekit.features_extractor import plp
from pydub.utils import mediainfo
import matplotlib.pyplot as plt
import librosa.display
import librosa
import numpy as np

# %matplotlib inline

np_handler = np.load("plp_data_and_label.npz")
raw_data, raw_label = np_handler['plp_data'], np_handler['plp_label']
print("shape of raw_data: ", np.shape(raw_data))
print("shape of raw_label: ", np.shape(raw_label))

test_data = np.array([raw_data[123, :, :], raw_data[321, :, :], raw_data[213, :, :], raw_data[103, :, :]])
print("shape of test_data: ", np.shape(test_data))
# Out:
# shape of raw_data:  (437, 998, 13)
# shape of raw_label:  (437,)
# shape of test_data:  (4, 998, 13)

# %%
for i in range(4):
    librosa.display.specshow(data=test_data[i, :, :], sr=44100)
    plt.show()
